# %%
import pandas as pd

# %%
df = pd.read_csv('overall-state.csv')
list(df.columns.values)
# Out:
# ['date',
#  'state_code',
#  'gender',
#  'age_bucket',
#  'n',
#  'weight_sums',
#  'pct_cli',
#  'pct_ili',
#  'pct_cli_anosmia_ageusia',
#  'pct_hh_cli',
#  'pct_cmnty_cli',
#  'pct_hh_fever',
#  'pct_hh_sore_throat',
#  'pct_hh_cough',
#  'pct_hh_shortness_of_breath',
#  'pct_hh_difficulty_breathing',
#  'mean_hh_cli_ct',
#  'mean_cmnty_cli_ct',
#  'pct_self_fever',
#  'pct_self_cough',
#  'pct_self_shortness_of_breath',
#  'pct_self_difficulty_breathing',
#  'pct_self_tiredness_or_exhaustion',
#  'pct_self_nasal_congestion',
#  'pct_self_runny_nose',
#  'pct_self_muscle_joint_aches',
#  'pct_self_sore_throat',
#  'pct_self_persistent_pain_pressure_in_chest',
#  'pct_self_nausea_vomiting',
#  'pct_self_diarrhea',
#  'pct_self_anosmia_ageusia',
#  'pct_self_other',
#  'pct_self_none_of_above',
#  'pct_self_multiple_symptoms',
#  'pct_tested_and_positive',
#  'pct_tested_and_negative',
#  'pct_tested_no_result',
#  'pct_could_not_get_tested',
#  'pct_did_not_try_to_get_tested',
#  'pct_worked_outside_home',
#  'pct_avoid_contact_all_or_most_time',
#  'mean_outside_hh_contact_at_work_ct',
#  'mean_outside_hh_contact_shopping_ct',
#  'mean_outside_hh_contact_in_social_gatherings_ct',
#  'pct_contact_covid_positive',
#  'pct_diabetes',
#  'pct_cancer',
#  'pct_heart_disease',
#  'pct_high_blood_pressure',
#  'pct_asthma',
#  'pct_chronic_lung_disease',
#  'pct_kidney_disease',
#  'pct_autoimmune_disorder',
#  'pct_no_above_medical_conditions',
#  'pct_multiple_medical_conditions',
#  'pct_cli_weighted',
#  'pct_ili_weighted',
#  'pct_cli_anosmia_ageusia_weighted',
#  'pct_hh_cli_weighted',
#  'pct_cmnty_cli_weighted',
#  'pct_hh_fever_weighted',
#  'pct_hh_sore_throat_weighted',
#  'pct_hh_cough_weighted',
#  'pct_hh_shortness_of_breath_weighted',
#  'pct_hh_difficulty_breathing_weighted',
#  'mean_hh_cli_ct_weighted',
#  'mean_cmnty_cli_ct_weighted',
#  'pct_self_fever_weighted',
#  'pct_self_cough_weighted',
#  'pct_self_shortness_of_breath_weighted',
#  'pct_self_difficulty_breathing_weighted',
#  'pct_self_tiredness_or_exhaustion_weighted',
#  'pct_self_nasal_congestion_weighted',
#  'pct_self_runny_nose_weighted',
#  'pct_self_muscle_joint_aches_weighted',
#  'pct_self_sore_throat_weighted',
#  'pct_self_persistent_pain_pressure_in_chest_weighted',
#  'pct_self_nausea_vomiting_weighted',
#  'pct_self_diarrhea_weighted',
#  'pct_self_anosmia_ageusia_weighted',
#  'pct_self_other_weighted',
#  'pct_self_none_of_above_weighted',
#  'pct_self_multiple_symptoms_weighted',
#  'pct_tested_and_positive_weighted',
#  'pct_tested_and_negative_weighted',
#  'pct_tested_no_result_weighted',
#  'pct_could_not_get_tested_weighted',
#  'pct_did_not_try_to_get_tested_weighted',
#  'pct_worked_outside_home_weighted',
#  'pct_avoid_contact_all_or_most_time_weighted',
#  'mean_outside_hh_contact_at_work_ct_weighted',
#  'mean_outside_hh_contact_shopping_ct_weighted',
#  'mean_outside_hh_contact_in_social_gatherings_ct_weighted',
#  'pct_contact_covid_positive_weighted',
#  'pct_diabetes_weighted',
#  'pct_cancer_weighted',
#  'pct_heart_disease_weighted',
#  'pct_high_blood_pressure_weighted',
#  'pct_asthma_weighted',
#  'pct_chronic_lung_disease_weighted',
#  'pct_kidney_disease_weighted',
#  'pct_autoimmune_disorder_weighted',
#  'pct_no_above_medical_conditions_weighted',
#  'pct_multiple_medical_conditions_weighted']

# %%
# state code to State name
abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
code2name = {y.lower():x for x,y in abbrev.items()}
code2name
# Out:
# {'al': 'Alabama',
#  'ak': 'Alaska',
#  'as': 'American Samoa',
#  'az': 'Arizona',
#  'ar': 'Arkansas',
#  'ca': 'California',
#  'co': 'Colorado',
#  'ct': 'Connecticut',
#  'de': 'Delaware',
#  'dc': 'District of Columbia',
#  'fl': 'Florida',
#  'ga': 'Georgia',
#  'gu': 'Guam',
#  'hi': 'Hawaii',
#  'id': 'Idaho',
#  'il': 'Illinois',
#  'in': 'Indiana',
#  'ia': 'Iowa',
#  'ks': 'Kansas',
#  'ky': 'Kentucky',
#  'la': 'Louisiana',
#  'me': 'Maine',
#  'md': 'Maryland',
#  'ma': 'Massachusetts',
#  'mi': 'Michigan',
#  'mn': 'Minnesota',
#  'ms': 'Mississippi',
#  'mo': 'Missouri',
#  'mt': 'Montana',
#  'ne': 'Nebraska',
#  'nv': 'Nevada',
#  'nh': 'New Hampshire',
#  'nj': 'New Jersey',
#  'nm': 'New Mexico',
#  'ny': 'New York',
#  'nc': 'North Carolina',
#  'nd': 'North Dakota',
#  'mp': 'Northern Mariana Islands',
#  'oh': 'Ohio',
#  'ok': 'Oklahoma',
#  'or': 'Oregon',
#  'pa': 'Pennsylvania',
#  'pr': 'Puerto Rico',
#  'ri': 'Rhode Island',
#  'sc': 'South Carolina',
#  'sd': 'South Dakota',
#  'tn': 'Tennessee',
#  'tx': 'Texas',
#  'ut': 'Utah',
#  'vt': 'Vermont',
#  'vi': 'Virgin Islands',
#  'va': 'Virginia',
#  'wa': 'Washington',
#  'wv': 'West Virginia',
#  'wi': 'Wisconsin',
#  'wy': 'Wyoming'}

# %%
df2  = df[['state_code', 'gender', 'age_bucket', 'pct_tested_and_positive_weighted']]
df2 = df2.replace({'state_code': code2name})
df2.head()
# Out:
#   state_code  gender age_bucket  pct_tested_and_positive_weighted
# 0     Alaska  female      18-34                            0.0000
# 1     Alaska  female      35-54                            0.0000
# 2     Alaska  female        55+                            0.0000
# 3    Alabama  female      18-34                            0.0883
# 4    Alabama  female      35-54                            0.0000

# %%
data_overall18 = df2.loc[(df2['gender'] == 'overall') & (df2['age_bucket'] == '18-34')][['state_code', 'pct_tested_and_positive_weighted']]
data_overall18 = data_overall18.groupby(data_overall18['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_overall18  = data_overall18 .rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_overall18.to_csv('overall-18.csv')
data_overall18
# Out:
#                       positives
# state_code
# Alabama                1.032806
# Alaska                 0.125896
# Arizona                0.765067
# Arkansas               0.542390
# California             0.572189
# Colorado               0.339550
# Connecticut            0.372281
# Delaware               0.470521
# District of Columbia   0.162930
# Florida                0.722013
# Georgia                0.834083
# Hawaii                 0.035890
# Idaho                  0.683110
# Illinois               0.533051
# Indiana                0.371215
# Iowa                   0.714438
# Kansas                 0.585052
# Kentucky               0.329378
# Louisiana              1.129012
# Maine                  0.083641
# Maryland               0.445837
# Massachusetts          0.312386
# Michigan               0.290786
# Minnesota              0.395971
# Mississippi            1.291863
# Missouri               0.457603
# Montana                0.273852
# Nebraska               0.574517
# Nevada                 0.775839
# New Hampshire          0.271254
# New Jersey             0.535589
# New Mexico             0.486501
# New York               0.408562
# North Carolina         0.433100
# North Dakota           0.423625
# Ohio                   0.278972
# Oklahoma               0.529045
# Oregon                 0.156498
# Pennsylvania           0.236786
# Rhode Island           0.437040
# South Carolina         0.711008
# South Dakota           0.490057
# Tennessee              0.558878
# Texas                  0.871360
# Utah                   0.498677
# Vermont                0.178780
# Virginia               0.386657
# Washington             0.280170
# West Virginia          0.174646
# Wisconsin              0.332378
# Wyoming                0.083442

# %%
data_overall35 = df2.loc[(df2['gender'] == 'overall') & (df2['age_bucket'] == '35-54')][['state_code', 'pct_tested_and_positive_weighted']]
data_overall35 = data_overall35.groupby(data_overall35['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_overall35  = data_overall35 .rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_overall35.to_csv('overall-35.csv')
data_overall35
# Out:
#                       positives
# state_code
# Alabama                0.887367
# Alaska                 0.263829
# Arizona                0.779834
# Arkansas               0.508715
# California             0.483993
# Colorado               0.297321
# Connecticut            0.385355
# Delaware               0.519246
# District of Columbia   0.701414
# Florida                0.686270
# Georgia                0.729684
# Hawaii                 0.153081
# Idaho                  0.552722
# Illinois               0.457487
# Indiana                0.388655
# Iowa                   0.563381
# Kansas                 0.379175
# Kentucky               0.311547
# Louisiana              1.005204
# Maine                  0.077972
# Maryland               0.386327
# Massachusetts          0.324249
# Michigan               0.316526
# Minnesota              0.303898
# Mississippi            0.938366
# Missouri               0.311278
# Montana                0.305646
# Nebraska               0.435426
# Nevada                 0.525367
# New Hampshire          0.165554
# New Jersey             0.567529
# New Mexico             0.273226
# New York               0.460571
# North Carolina         0.366489
# North Dakota           0.480454
# Ohio                   0.259244
# Oklahoma               0.437218
# Oregon                 0.208029
# Pennsylvania           0.257176
# Rhode Island           0.558273
# South Carolina         0.702204
# South Dakota           0.471831
# Tennessee              0.451639
# Texas                  0.809088
# Utah                   0.532981
# Vermont                0.098153
# Virginia               0.316690
# Washington             0.298563
# West Virginia          0.224023
# Wisconsin              0.253885
# Wyoming                0.198445

# %%
data_overall55 = df2.loc[(df2['gender'] == 'overall') & (df2['age_bucket'] == '55+')][['state_code', 'pct_tested_and_positive_weighted']]
data_overall55 = data_overall55.groupby(data_overall55['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_overall55  = data_overall55 .rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_overall55.to_csv('overall-55.csv')
data_overall55
# Out:
#                       positives
# state_code
# Alabama                0.556826
# Alaska                 0.161610
# Arizona                0.353014
# Arkansas               0.311546
# California             0.233386
# Colorado               0.227041
# Connecticut            0.341135
# Delaware               0.210329
# District of Columbia   0.000000
# Florida                0.383303
# Georgia                0.545225
# Hawaii                 0.082973
# Idaho                  0.347683
# Illinois               0.305891
# Indiana                0.322062
# Iowa                   0.378689
# Kansas                 0.260424
# Kentucky               0.252472
# Louisiana              0.830049
# Maine                  0.092870
# Maryland               0.271222
# Massachusetts          0.313160
# Michigan               0.257870
# Minnesota              0.191374
# Mississippi            0.697984
# Missouri               0.298169
# Montana                0.174312
# Nebraska               0.244011
# Nevada                 0.274784
# New Hampshire          0.143975
# New Jersey             0.455783
# New Mexico             0.212822
# New York               0.389064
# North Carolina         0.234838
# North Dakota           0.151862
# Ohio                   0.226853
# Oklahoma               0.383463
# Oregon                 0.124077
# Pennsylvania           0.186820
# Rhode Island           0.274810
# South Carolina         0.388399
# South Dakota           0.277587
# Tennessee              0.336507
# Texas                  0.476989
# Utah                   0.397210
# Vermont                0.095505
# Virginia               0.234180
# Washington             0.182302
# West Virginia          0.127437
# Wisconsin              0.234378
# Wyoming                0.104441

# %%
data_female35 = df2.loc[(df2['gender'] == 'female') & (df2['age_bucket'] == '35-54')][['state_code', 'pct_tested_and_positive_weighted']]
data_female35 = data_female35.groupby(data_female35['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_female35  = data_female35 .rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_female35.to_csv('female-35.csv')
data_female35
# Out:
#                       positives
# state_code
# Alabama                1.121215
# Alaska                 0.157509
# Arizona                0.936109
# Arkansas               0.600987
# California             0.545112
# Colorado               0.319726
# Connecticut            0.461668
# Delaware               0.643913
# District of Columbia   0.000000
# Florida                0.792959
# Georgia                0.839904
# Hawaii                 0.107872
# Idaho                  0.659398
# Illinois               0.512136
# Indiana                0.455632
# Iowa                   0.640577
# Kansas                 0.462225
# Kentucky               0.357143
# Louisiana              1.264832
# Maine                  0.109279
# Maryland               0.388564
# Massachusetts          0.370800
# Michigan               0.374788
# Minnesota              0.343404
# Mississippi            1.140780
# Missouri               0.332247
# Montana                0.283927
# Nebraska               0.496463
# Nevada                 0.757380
# New Hampshire          0.234859
# New Jersey             0.631138
# New Mexico             0.344788
# New York               0.537830
# North Carolina         0.431833
# North Dakota           0.451513
# Ohio                   0.295404
# Oklahoma               0.540302
# Oregon                 0.229369
# Pennsylvania           0.268430
# Rhode Island           0.777713
# South Carolina         0.846846
# South Dakota           0.724254
# Tennessee              0.526156
# Texas                  0.976928
# Utah                   0.592589
# Vermont                0.217684
# Virginia               0.348447
# Washington             0.352937
# West Virginia          0.217685
# Wisconsin              0.322372
# Wyoming                0.205417

# %%
data_female55 = df2.loc[(df2['gender'] == 'female') & (df2['age_bucket'] == '55+')][['state_code', 'pct_tested_and_positive_weighted']]
data_female55 = data_female55.groupby(data_female55['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_female55  = data_female55.rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_female55.to_csv('female-55.csv')
data_female55
# Out:
#                       positives
# state_code
# Alabama                0.584491
# Alaska                 0.000000
# Arizona                0.408368
# Arkansas               0.353383
# California             0.230386
# Colorado               0.227199
# Connecticut            0.358617
# Delaware               0.298376
# District of Columbia   0.000000
# Florida                0.384509
# Georgia                0.600013
# Hawaii                 0.062717
# Idaho                  0.385287
# Illinois               0.326958
# Indiana                0.356558
# Iowa                   0.386595
# Kansas                 0.246956
# Kentucky               0.269814
# Louisiana              0.902857
# Maine                  0.085339
# Maryland               0.265645
# Massachusetts          0.334039
# Michigan               0.267700
# Minnesota              0.185470
# Mississippi            0.873058
# Missouri               0.277846
# Montana                0.203309
# Nebraska               0.269309
# Nevada                 0.322525
# New Hampshire          0.137950
# New Jersey             0.447983
# New Mexico             0.233043
# New York               0.361414
# North Carolina         0.241734
# North Dakota           0.000000
# Ohio                   0.243052
# Oklahoma               0.419402
# Oregon                 0.108565
# Pennsylvania           0.183511
# Rhode Island           0.293986
# South Carolina         0.445854
# South Dakota           0.192027
# Tennessee              0.346530
# Texas                  0.518508
# Utah                   0.358898
# Vermont                0.101597
# Virginia               0.255347
# Washington             0.209936
# West Virginia          0.116960
# Wisconsin              0.206847
# Wyoming                0.138877

# %%
data_female18 = df2.loc[(df2['gender'] == 'female') & (df2['age_bucket'] == '18-34')][['state_code', 'pct_tested_and_positive_weighted']]
data_female18 = data_female18.groupby(data_female18['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_female18  = data_female18.rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_female18.to_csv('female-18.csv')
data_female18
# Out:
#                       positives
# state_code
# Alabama                1.329227
# Alaska                 0.000000
# Arizona                0.988500
# Arkansas               0.619238
# California             0.631866
# Colorado               0.312630
# Connecticut            0.464705
# Delaware               0.685128
# District of Columbia   0.214883
# Florida                0.797925
# Georgia                0.986039
# Hawaii                 0.000000
# Idaho                  0.938646
# Illinois               0.563967
# Indiana                0.452595
# Iowa                   1.024076
# Kansas                 0.692247
# Kentucky               0.347407
# Louisiana              1.567221
# Maine                  0.106403
# Maryland               0.507405
# Massachusetts          0.388349
# Michigan               0.336724
# Minnesota              0.432432
# Mississippi            1.480021
# Missouri               0.559736
# Montana                0.237846
# Nebraska               0.651667
# Nevada                 0.856174
# New Hampshire          0.297573
# New Jersey             0.566082
# New Mexico             0.396457
# New York               0.459563
# North Carolina         0.431695
# North Dakota           0.489184
# Ohio                   0.331544
# Oklahoma               0.564689
# Oregon                 0.179955
# Pennsylvania           0.295969
# Rhode Island           0.619170
# South Carolina         0.834964
# South Dakota           0.604589
# Tennessee              0.673379
# Texas                  0.964476
# Utah                   0.573357
# Vermont                0.283188
# Virginia               0.386676
# Washington             0.300914
# West Virginia          0.231993
# Wisconsin              0.388593
# Wyoming                0.187663

# %%
data_male55 = df2.loc[(df2['gender'] == 'male') & (df2['age_bucket'] == '55+')][['state_code', 'pct_tested_and_positive_weighted']]
data_male55 = data_male55.groupby(data_male55['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_male55  = data_male55.rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_male55.to_csv('male-55.csv')
data_male55
# Out:
#                 positives
# state_code
# Alabama          0.536373
# Alaska           0.000000
# Arizona          0.290290
# Arkansas         0.262654
# California       0.238723
# Colorado         0.226947
# Connecticut      0.322279
# Delaware         0.243963
# Florida          0.381773
# Georgia          0.483146
# Hawaii           0.000000
# Idaho            0.194376
# Illinois         0.283711
# Indiana          0.282730
# Iowa             0.369970
# Kansas           0.302466
# Kentucky         0.231643
# Louisiana        0.742756
# Maine            0.102686
# Maryland         0.273102
# Massachusetts    0.256021
# Michigan         0.246336
# Minnesota        0.200032
# Mississippi      0.489754
# Missouri         0.323297
# Montana          0.400308
# Nebraska         0.150502
# Nevada           0.233072
# New Hampshire    0.152359
# New Jersey       0.447765
# New Mexico       0.217509
# New York         0.427390
# North Carolina   0.231336
# North Dakota     0.000000
# Ohio             0.208333
# Oklahoma         0.346672
# Oregon           0.142607
# Pennsylvania     0.191940
# Rhode Island     0.162433
# South Carolina   0.323039
# South Dakota     0.704733
# Tennessee        0.325031
# Texas            0.433506
# Utah             0.453236
# Vermont          0.000000
# Virginia         0.209234
# Washington       0.155276
# West Virginia    0.136773
# Wisconsin        0.266614
# Wyoming          0.000000

# %%
data_male35 = df2.loc[(df2['gender'] == 'male') & (df2['age_bucket'] == '35-54')][['state_code', 'pct_tested_and_positive_weighted']]
data_male35 = data_male35.groupby(data_male35['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_male35  = data_male35.rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_male35.to_csv('male-35.csv')
data_male35
# Out:
#                       positives
# state_code
# Alabama                0.692506
# Alaska                 0.000000
# Arizona                0.627469
# Arkansas               0.510173
# California             0.388308
# Colorado               0.279564
# Connecticut            0.328772
# Delaware               0.411787
# District of Columbia   0.000000
# Florida                0.571731
# Georgia                0.610377
# Hawaii                 0.000000
# Idaho                  0.338403
# Illinois               0.401757
# Indiana                0.318799
# Iowa                   0.511947
# Kansas                 0.362106
# Kentucky               0.283033
# Louisiana              0.748162
# Maine                  0.024730
# Maryland               0.408123
# Massachusetts          0.283665
# Michigan               0.255286
# Minnesota              0.269109
# Mississippi            0.791257
# Missouri               0.296437
# Montana                0.070935
# Nebraska               0.357629
# Nevada                 0.420402
# New Hampshire          0.207067
# New Jersey             0.506654
# New Mexico             0.356669
# New York               0.382800
# North Carolina         0.300295
# North Dakota           0.000000
# Ohio                   0.221204
# Oklahoma               0.360734
# Oregon                 0.188699
# Pennsylvania           0.247399
# Rhode Island           0.436500
# South Carolina         0.572816
# South Dakota           0.285183
# Tennessee              0.385116
# Texas                  0.631467
# Utah                   0.528660
# Vermont                0.000000
# Virginia               0.285357
# Washington             0.250000
# West Virginia          0.224046
# Wisconsin              0.186737
# Wyoming                0.000000

# %%
data_male18 = df2.loc[(df2['gender'] == 'male') & (df2['age_bucket'] == '18-34')][['state_code', 'pct_tested_and_positive_weighted']]
data_male18 = data_male18.groupby(data_male18['state_code']).aggregate({'pct_tested_and_positive_weighted':'mean'})
data_male18  = data_male18.rename(columns={'state_code': 'states', 'pct_tested_and_positive_weighted': 'positives'})
data_male18.to_csv('male-18.csv')
data_male18
# Out:
#                       positives
# state_code
# Alabama                0.919745
# Alaska                 0.000000
# Arizona                0.769972
# Arkansas               0.299911
# California             0.511957
# Colorado               0.415840
# Connecticut            0.385556
# District of Columbia   0.282967
# Florida                0.650090
# Georgia                0.830093
# Hawaii                 0.000000
# Idaho                  0.428206
# Illinois               0.506450
# Indiana                0.337996
# Iowa                   0.583328
# Kansas                 0.439238
# Kentucky               0.339665
# Louisiana              0.973439
# Maine                  0.183520
# Maryland               0.608184
# Massachusetts          0.307479
# Michigan               0.258605
# Minnesota              0.477307
# Mississippi            0.544393
# Missouri               0.403464
# Montana                0.000000
# Nebraska               0.575971
# Nevada                 0.216833
# New Hampshire          0.000000
# New Jersey             0.657768
# New Mexico             0.067943
# New York               0.352259
# North Carolina         0.504760
# North Dakota           0.000000
# Ohio                   0.224120
# Oklahoma               0.594603
# Oregon                 0.112372
# Pennsylvania           0.174239
# Rhode Island           0.000000
# South Carolina         0.818546
# South Dakota           0.000000
# Tennessee              0.570022
# Texas                  0.767260
# Utah                   0.548949
# Virginia               0.452010
# Washington             0.303849
# West Virginia          0.000000
# Wisconsin              0.315625
